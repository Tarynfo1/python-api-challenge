# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from datetime import datetime
from scipy.stats import linregress

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# Create output file
output_file = "output_data/cities.csv"

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 630

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# Define an empty list to fetch the weather data for each city
city_data = []
coord = []
lat = []
lng = []
temp = []
max_temp = []
humidity = []
clouds = []
wind = []
country = []
date = []


# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0
        time.sleep(60)

    # Create endpoint URL with each city
    city_url = query_url = f"{url}appid={weather_api_key}&units={units}&q="
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(query_url + city).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    #If an error is experienced, skip the city
    except KeyError:
        print("City not found. Skipping...")

        pass
              
# Indicate that Data Loading is complete 

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | isafjordur
# Processing Record 2 of Set 1 | thompson
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | zumpango del rio
# Processing Record 5 of Set 1 | coquimbo
# Processing Record 6 of Set 1 | codrington
# Processing Record 7 of Set 1 | moree
# Processing Record 8 of Set 1 | argo
# Processing Record 9 of Set 1 | blackmans bay
# Processing Record 10 of Set 1 | kavaratti
# Processing Record 11 of Set 1 | edinburgh of the seven seas
# Processing Record 12 of Set 1 | grytviken
# Processing Record 13 of Set 1 | talnakh
# Processing Record 14 of Set 1 | bethel
# Processing Record 15 of Set 1 | port alfred
# Processing Record 16 of Set 1 | coquimatlan
# Processing Record 17 of Set 1 | chatel-saint-denis
# Processing Record 18 of Set 1 | bredasdorp
# Processing Record 19 of Set 1 | port mathurin
# Processing Record 20 of Set 1 | port-aux-francais
# Processing Record 21 of Set 1 | santa rosa
# Processing Record 22 of Set 1 | puerto natales
# Processing Record 23 of Set 1 | alagoinha
# Processing Record 24 of Set 1 | sambava
# Processing Record 25 of Set 1 | boyolangu
# Processing Record 26 of Set 1 | iqaluit
# Processing Record 27 of Set 1 | whitehorse
# Processing Record 28 of Set 1 | invercargill
# Processing Record 29 of Set 1 | chonchi
# Processing Record 30 of Set 1 | saipan
# Processing Record 31 of Set 1 | ilulissat
# Processing Record 32 of Set 1 | vicuna
# Processing Record 33 of Set 1 | atafu village
# Processing Record 34 of Set 1 | qaqortoq
# Processing Record 35 of Set 1 | shubarkuduk
# Processing Record 36 of Set 1 | adamstown
# Processing Record 37 of Set 1 | uturoa
# Processing Record 38 of Set 1 | orosei
# Processing Record 39 of Set 1 | papatowai
# Processing Record 40 of Set 1 | smithers
# Processing Record 41 of Set 1 | lihue
# Processing Record 42 of Set 1 | labrador city
# Processing Record 43 of Set 1 | cold lake
# Processing Record 44 of Set 1 | puerto san carlos
# City not found. Skipping...
# Processing Record 45 of Set 1 | villa alberto andres alvarado aramburo
# City not found. Skipping...
# Processing Record 46 of Set 1 | jinchang
# Processing Record 47 of Set 1 | tralee
# Processing Record 48 of Set 1 | flying fish cove
# Processing Record 49 of Set 1 | villa rica
# Processing Record 50 of Set 1 | jayapura
# Processing Record 0 of Set 2 | nemuro
# Processing Record 1 of Set 2 | mount gambier
# Processing Record 2 of Set 2 | ribeira grande
# Processing Record 3 of Set 2 | lebu
# Processing Record 4 of Set 2 | abraham's bay
# City not found. Skipping...
# Processing Record 5 of Set 2 | cascais
# Processing Record 6 of Set 2 | chibougamau
# Processing Record 7 of Set 2 | constantia
# Processing Record 8 of Set 2 | hermanus
# Processing Record 9 of Set 2 | san luis de la loma
# Processing Record 10 of Set 2 | punta arenas
# Processing Record 11 of Set 2 | dapchi
# Processing Record 12 of Set 2 | la ronge
# Processing Record 13 of Set 2 | calgary
# Processing Record 14 of Set 2 | leshan
# Processing Record 15 of Set 2 | waitangi
# Processing Record 16 of Set 2 | fort bragg
# Processing Record 17 of Set 2 | iskateley
# Processing Record 18 of Set 2 | kununurra
# Processing Record 19 of Set 2 | yellowknife
# Processing Record 20 of Set 2 | lionel town
# Processing Record 21 of Set 2 | pailon
# Processing Record 22 of Set 2 | palikir - national government center
# Processing Record 23 of Set 2 | cidreira
# Processing Record 24 of Set 2 | tiksi
# Processing Record 25 of Set 2 | turpan
# Processing Record 26 of Set 2 | pisco
# Processing Record 27 of Set 2 | domna
# Processing Record 28 of Set 2 | cuito
# Processing Record 29 of Set 2 | ust-nera
# Processing Record 30 of Set 2 | port elizabeth
# Processing Record 31 of Set 2 | diebougou
# Processing Record 32 of Set 2 | nishinoomote
# Processing Record 33 of Set 2 | tsetserleg
# Processing Record 34 of Set 2 | vallenar
# Processing Record 35 of Set 2 | jamestown
# Processing Record 36 of Set 2 | chernyshevsk
# Processing Record 37 of Set 2 | georgetown
# Processing Record 38 of Set 2 | itambe
# Processing Record 39 of Set 2 | nagqu
# Processing Record 40 of Set 2 | zhaobaoshan
# Processing Record 41 of Set 2 | suwayr
# Processing Record 42 of Set 2 | alofi
# Processing Record 43 of Set 2 | prince rupert
# Processing Record 44 of Set 2 | tongouson
# Processing Record 45 of Set 2 | nuuk
# Processing Record 46 of Set 2 | shihezi
# Processing Record 47 of Set 2 | kaleke mandi
# Processing Record 48 of Set 2 | stanley
# Processing Record 49 of Set 2 | tobi village
# City not found. Skipping...
# Processing Record 0 of Set 3 | fengrun
# Processing Record 1 of Set 3 | abu dhabi
# Processing Record 2 of Set 3 | olonkinbyen
# Processing Record 3 of Set 3 | margaret river
# Processing Record 4 of Set 3 | udachny
# Processing Record 5 of Set 3 | new norfolk
# Processing Record 6 of Set 3 | isyangulovo
# Processing Record 7 of Set 3 | okha
# Processing Record 8 of Set 3 | charters towers
# Processing Record 9 of Set 3 | deqen
# Processing Record 10 of Set 3 | taoudenni
# Processing Record 11 of Set 3 | coahuayana de hidalgo
# Processing Record 12 of Set 3 | dame-marie
# Processing Record 13 of Set 3 | klyuchi
# Processing Record 14 of Set 3 | hayma'
# City not found. Skipping...
# Processing Record 15 of Set 3 | mumford
# Processing Record 16 of Set 3 | petropavlovsk-kamchatsky
# Processing Record 17 of Set 3 | puerto ayora
# Processing Record 18 of Set 3 | enewetak
# Processing Record 19 of Set 3 | broome
# Processing Record 20 of Set 3 | hadibu
# Processing Record 21 of Set 3 | moyynkum
# Processing Record 22 of Set 3 | wailua homesteads
# Processing Record 23 of Set 3 | taiohae
# City not found. Skipping...
# Processing Record 24 of Set 3 | fort st. john
# Processing Record 25 of Set 3 | longyearbyen
# Processing Record 26 of Set 3 | albany
# Processing Record 27 of Set 3 | sechura
# Processing Record 28 of Set 3 | margate
# Processing Record 29 of Set 3 | baiquan
# Processing Record 30 of Set 3 | alta
# Processing Record 31 of Set 3 | vorgashor
# Processing Record 32 of Set 3 | susuman
# Processing Record 33 of Set 3 | mejit
# Processing Record 34 of Set 3 | bilibino
# Processing Record 35 of Set 3 | pollock pines
# Processing Record 36 of Set 3 | bereeda
# Processing Record 37 of Set 3 | baruun-urt
# Processing Record 38 of Set 3 | vilyuysk
# Processing Record 39 of Set 3 | ahau
# City not found. Skipping...
# Processing Record 40 of Set 3 | port lincoln
# Processing Record 41 of Set 3 | chadron
# Processing Record 42 of Set 3 | dashtobod
# Processing Record 43 of Set 3 | san patricio
# Processing Record 44 of Set 3 | tucuma
# Processing Record 45 of Set 3 | walvis bay
# Processing Record 46 of Set 3 | minas de marcona
# Processing Record 47 of Set 3 | armacao de buzios
# Processing Record 48 of Set 3 | sawakin
# Processing Record 49 of Set 3 | badger
# Processing Record 0 of Set 4 | chapada dos guimaraes
# Processing Record 1 of Set 4 | miyanoura
# City not found. Skipping...
# Processing Record 2 of Set 4 | gadzhiyevo
# Processing Record 3 of Set 4 | goundam
# Processing Record 4 of Set 4 | live oak
# Processing Record 5 of Set 4 | aasiaat
# Processing Record 6 of Set 4 | acapulco de juarez
# Processing Record 7 of Set 4 | shunyi
# Processing Record 8 of Set 4 | coin
# Processing Record 9 of Set 4 | mata-utu
# Processing Record 10 of Set 4 | alice springs
# Processing Record 11 of Set 4 | taunggyi
# Processing Record 12 of Set 4 | hilo
# Processing Record 13 of Set 4 | el sauzal de rodriguez
# Processing Record 14 of Set 4 | kurmuk
# Processing Record 15 of Set 4 | nouadhibou
# Processing Record 16 of Set 4 | college
# Processing Record 17 of Set 4 | shahabad
# Processing Record 18 of Set 4 | wokha
# Processing Record 19 of Set 4 | junction city
# Processing Record 20 of Set 4 | bathsheba
# Processing Record 21 of Set 4 | tazovsky
# Processing Record 22 of Set 4 | yuanlin
# Processing Record 23 of Set 4 | altamira
# Processing Record 24 of Set 4 | toga village
# City not found. Skipping...
# Processing Record 25 of Set 4 | gisborne
# Processing Record 26 of Set 4 | tanrake village
# City not found. Skipping...
# Processing Record 27 of Set 4 | bougouni
# Processing Record 28 of Set 4 | ola
# Processing Record 29 of Set 4 | illapel
# Processing Record 30 of Set 4 | kazanskoye
# Processing Record 31 of Set 4 | akureyri
# Processing Record 32 of Set 4 | sault ste. marie
# Processing Record 33 of Set 4 | avarua
# Processing Record 34 of Set 4 | doka
# Processing Record 35 of Set 4 | katsuren-haebaru
# Processing Record 36 of Set 4 | sefrou
# Processing Record 37 of Set 4 | luderitz
# Processing Record 38 of Set 4 | lompoc
# Processing Record 39 of Set 4 | the pas
# Processing Record 40 of Set 4 | hammerfest
# Processing Record 41 of Set 4 | hithadhoo
# Processing Record 42 of Set 4 | teguise
# Processing Record 43 of Set 4 | palmer
# Processing Record 44 of Set 4 | dawson creek
# Processing Record 45 of Set 4 | dudinka
# Processing Record 46 of Set 4 | nsanje
# Processing Record 47 of Set 4 | torit
# Processing Record 48 of Set 4 | vila franca do campo
# Processing Record 49 of Set 4 | yinchuan
# Processing Record 0 of Set 5 | auki
# Processing Record 1 of Set 5 | najran
# Processing Record 2 of Set 5 | haiku-pauwela
# Processing Record 3 of Set 5 | aykhal
# Processing Record 4 of Set 5 | st. john's
# Processing Record 5 of Set 5 | colonia
# Processing Record 6 of Set 5 | kamuli
# Processing Record 7 of Set 5 | kangding
# Processing Record 8 of Set 5 | trevelin
# Processing Record 9 of Set 5 | keflavik
# Processing Record 10 of Set 5 | singaparna
# Processing Record 11 of Set 5 | sao joao dos patos
# Processing Record 12 of Set 5 | dar chioukh
# Processing Record 13 of Set 5 | kolonia
# Processing Record 14 of Set 5 | west island
# Processing Record 15 of Set 5 | marrakesh
# Processing Record 16 of Set 5 | tsengel
# Processing Record 17 of Set 5 | nova sintra
# Processing Record 18 of Set 5 | mramani
# Processing Record 19 of Set 5 | inhambane
# Processing Record 20 of Set 5 | tura
# Processing Record 21 of Set 5 | carnarvon
# Processing Record 22 of Set 5 | cargados carajos
# City not found. Skipping...
# Processing Record 23 of Set 5 | callao
# Processing Record 24 of Set 5 | myeik
# Processing Record 25 of Set 5 | gueckedou
# Processing Record 26 of Set 5 | independence
# Processing Record 27 of Set 5 | kapa'a
# Processing Record 28 of Set 5 | batang
# Processing Record 29 of Set 5 | mount isa
# Processing Record 30 of Set 5 | sofifi
# City not found. Skipping...
# Processing Record 31 of Set 5 | prado
# Processing Record 32 of Set 5 | severo-yeniseyskiy
# Processing Record 33 of Set 5 | midelt
# Processing Record 34 of Set 5 | glace bay
# Processing Record 35 of Set 5 | gaalkacyo
# Processing Record 36 of Set 5 | port macquarie
# Processing Record 37 of Set 5 | kuqa
# Processing Record 38 of Set 5 | djambala
# Processing Record 39 of Set 5 | rajpur
# Processing Record 40 of Set 5 | fortuna
# Processing Record 41 of Set 5 | page
# Processing Record 42 of Set 5 | pacific grove
# Processing Record 43 of Set 5 | komusan il-tong
# Processing Record 44 of Set 5 | as sulayyil
# Processing Record 45 of Set 5 | georgiyevka
# Processing Record 46 of Set 5 | malindi
# Processing Record 47 of Set 5 | ibresi
# Processing Record 48 of Set 5 | tofol
# Processing Record 49 of Set 5 | anadyr
# Processing Record 0 of Set 6 | sisimiut
# Processing Record 1 of Set 6 | tecpan de galeana
# Processing Record 2 of Set 6 | limbdi
# Processing Record 3 of Set 6 | kenai
# Processing Record 4 of Set 6 | guateque
# Processing Record 5 of Set 6 | arbus
# Processing Record 6 of Set 6 | acarau
# Processing Record 7 of Set 6 | jerome
# Processing Record 8 of Set 6 | tanout
# Processing Record 9 of Set 6 | dakhla
# Processing Record 10 of Set 6 | san antonio de pale
# Processing Record 11 of Set 6 | shalqar
# Processing Record 12 of Set 6 | crixas
# Processing Record 13 of Set 6 | at taj
# Processing Record 14 of Set 6 | benguela
# Processing Record 15 of Set 6 | horta
# Processing Record 16 of Set 6 | nadvoitsy
# Processing Record 17 of Set 6 | morfou
# Processing Record 18 of Set 6 | arraial do cabo
# Processing Record 19 of Set 6 | ivdel'
# Processing Record 20 of Set 6 | bamboo flat
# Processing Record 21 of Set 6 | rikaze
# Processing Record 22 of Set 6 | guercif
# Processing Record 23 of Set 6 | acajutla
# Processing Record 24 of Set 6 | rehoboth
# Processing Record 25 of Set 6 | namsos
# Processing Record 26 of Set 6 | geraldton
# Processing Record 27 of Set 6 | changyon
# Processing Record 28 of Set 6 | nuea khlong
# Processing Record 29 of Set 6 | livingston
# Processing Record 30 of Set 6 | vernal
# Processing Record 31 of Set 6 | kralendijk
# Processing Record 32 of Set 6 | utrik
# Processing Record 33 of Set 6 | alakurtti
# Processing Record 34 of Set 6 | rongelap
# Processing Record 35 of Set 6 | sao vicente
# Processing Record 36 of Set 6 | saynshand
# Processing Record 37 of Set 6 | kill devil hills
# Processing Record 38 of Set 6 | bouznika
# Processing Record 39 of Set 6 | tourlaville
# Processing Record 40 of Set 6 | campo gallo
# Processing Record 41 of Set 6 | fort mcmurray
# Processing Record 42 of Set 6 | enoch
# Processing Record 43 of Set 6 | roma
# Processing Record 44 of Set 6 | kodiak
# Processing Record 45 of Set 6 | al kharj
# Processing Record 46 of Set 6 | usinsk
# Processing Record 47 of Set 6 | cartagena
# Processing Record 48 of Set 6 | cill airne
# Processing Record 49 of Set 6 | gueltat zemmour
# City not found. Skipping...
# Processing Record 0 of Set 7 | suamico
# Processing Record 1 of Set 7 | baependi
# Processing Record 2 of Set 7 | la plata
# Processing Record 3 of Set 7 | victoria falls
# Processing Record 4 of Set 7 | yaren
# Processing Record 5 of Set 7 | arkhangel'sk
# Processing Record 6 of Set 7 | afif
# Processing Record 7 of Set 7 | itoman
# Processing Record 8 of Set 7 | paris
# Processing Record 9 of Set 7 | qamdo
# Processing Record 10 of Set 7 | richards bay
# Processing Record 11 of Set 7 | zaozersk
# Processing Record 12 of Set 7 | lata
# Processing Record 13 of Set 7 | nikolayevsk-on-amure
# Processing Record 14 of Set 7 | aginskoye
# Processing Record 15 of Set 7 | oranjemund
# Processing Record 16 of Set 7 | ulladulla
# Processing Record 17 of Set 7 | saint-pierre
# Processing Record 18 of Set 7 | nizhneangarsk
# Processing Record 19 of Set 7 | tosontsengel
# Processing Record 20 of Set 7 | fuvahmulah
# City not found. Skipping...
# Processing Record 21 of Set 7 | kwolla
# Processing Record 22 of Set 7 | lagodekhi
# Processing Record 23 of Set 7 | howard springs
# Processing Record 24 of Set 7 | south hedland
# Processing Record 25 of Set 7 | cepu
# Processing Record 26 of Set 7 | dhidhdhoo
# Processing Record 27 of Set 7 | hawaiian paradise park
# Processing Record 28 of Set 7 | ancud
# Processing Record 29 of Set 7 | rayside-balfour
# City not found. Skipping...
# Processing Record 30 of Set 7 | kakori
# Processing Record 31 of Set 7 | beibei
# Processing Record 32 of Set 7 | la passe
# Processing Record 33 of Set 7 | motygino
# Processing Record 34 of Set 7 | mukalla
# Processing Record 35 of Set 7 | namibe
# Processing Record 36 of Set 7 | clearlake
# Processing Record 37 of Set 7 | kailua-kona
# Processing Record 38 of Set 7 | chadan
# Processing Record 39 of Set 7 | kataragama
# City not found. Skipping...
# Processing Record 40 of Set 7 | maues
# Processing Record 41 of Set 7 | maryborough
# Processing Record 42 of Set 7 | ambalangoda
# Processing Record 43 of Set 7 | alo
# Processing Record 44 of Set 7 | lerwick
# Processing Record 45 of Set 7 | bosobolo
# Processing Record 46 of Set 7 | jinghong
# Processing Record 47 of Set 7 | spring creek
# Processing Record 48 of Set 7 | grants
# Processing Record 49 of Set 7 | hobyo
# Processing Record 0 of Set 8 | pamandzi
# Processing Record 1 of Set 8 | sal rei
# Processing Record 2 of Set 8 | novyy urengoy
# Processing Record 3 of Set 8 | tamandare
# Processing Record 4 of Set 8 | san agustin de valle fertil
# Processing Record 5 of Set 8 | muravlenko
# Processing Record 6 of Set 8 | chernyshevskiy
# Processing Record 7 of Set 8 | solleftea
# Processing Record 8 of Set 8 | ahero
# Processing Record 9 of Set 8 | bangolo
# Processing Record 10 of Set 8 | mana
# Processing Record 11 of Set 8 | placido de castro
# Processing Record 12 of Set 8 | binuangan
# Processing Record 13 of Set 8 | ormara
# Processing Record 14 of Set 8 | pibor
# City not found. Skipping...
# Processing Record 15 of Set 8 | kamareddi
# Processing Record 16 of Set 8 | egilsstadir
# Processing Record 17 of Set 8 | funafuti
# Processing Record 18 of Set 8 | mossel bay
# Processing Record 19 of Set 8 | yangquan
# Processing Record 20 of Set 8 | happy valley-goose bay
# Processing Record 21 of Set 8 | lospalos
# Processing Record 22 of Set 8 | malvan
# Processing Record 23 of Set 8 | port saint john's
# Processing Record 24 of Set 8 | andergrove
# Processing Record 25 of Set 8 | lakatoro
# Processing Record 26 of Set 8 | east london
# Processing Record 27 of Set 8 | berezovyy
# Processing Record 28 of Set 8 | palangkaraya
# Processing Record 29 of Set 8 | lubang
# Processing Record 30 of Set 8 | bulawayo
# Processing Record 31 of Set 8 | puerto deseado
# Processing Record 32 of Set 8 | ruidoso
# Processing Record 33 of Set 8 | xai-xai
# Processing Record 34 of Set 8 | las khorey
# Processing Record 35 of Set 8 | contai
# Processing Record 36 of Set 8 | point pedro
# Processing Record 37 of Set 8 | gornyy
# Processing Record 38 of Set 8 | olinda
# Processing Record 39 of Set 8 | cabo san lucas
# Processing Record 40 of Set 8 | selfoss
# Processing Record 41 of Set 8 | kuanda
# Processing Record 42 of Set 8 | dwarka
# Processing Record 43 of Set 8 | visby
# Processing Record 44 of Set 8 | puerto baquerizo moreno
# Processing Record 45 of Set 8 | el granada
# Processing Record 46 of Set 8 | dalian
# Processing Record 47 of Set 8 | tabou
# Processing Record 48 of Set 8 | kone
# Processing Record 49 of Set 8 | arar
# Processing Record 0 of Set 9 | bubaque
# Processing Record 1 of Set 9 | dajal
# Processing Record 2 of Set 9 | hamilton
# Processing Record 3 of Set 9 | manta
# Processing Record 4 of Set 9 | tara
# Processing Record 5 of Set 9 | pangody
# Processing Record 6 of Set 9 | mombetsu
# Processing Record 7 of Set 9 | souillac
# Processing Record 8 of Set 9 | mhamid
# Processing Record 9 of Set 9 | nadym
# Processing Record 10 of Set 9 | ibiruba
# Processing Record 11 of Set 9 | craig
# Processing Record 12 of Set 9 | santyoku
# Processing Record 13 of Set 9 | belgrade
# Processing Record 14 of Set 9 | tumayr
# Processing Record 15 of Set 9 | grand falls-windsor
# Processing Record 16 of Set 9 | utena
# Processing Record 17 of Set 9 | ranavav
# Processing Record 18 of Set 9 | black point
# Processing Record 19 of Set 9 | novopskov
# Processing Record 20 of Set 9 | jorpeland
# Processing Record 21 of Set 9 | porto novo
# Processing Record 22 of Set 9 | mar del plata
# Processing Record 23 of Set 9 | kutahya
# Processing Record 24 of Set 9 | colchani
# Processing Record 25 of Set 9 | shakawe
# Processing Record 26 of Set 9 | vilyuchinsk
# Processing Record 27 of Set 9 | santa maria da vitoria
# Processing Record 28 of Set 9 | morondava
# Processing Record 29 of Set 9 | pangai
# Processing Record 30 of Set 9 | dunedin
# Processing Record 31 of Set 9 | bengkulu
# Processing Record 32 of Set 9 | el nido
# Processing Record 33 of Set 9 | erdenet
# Processing Record 34 of Set 9 | lhuentse
# Processing Record 35 of Set 9 | burang
# Processing Record 36 of Set 9 | portland
# Processing Record 37 of Set 9 | keningau
# Processing Record 38 of Set 9 | chengde
# Processing Record 39 of Set 9 | elko
# Processing Record 40 of Set 9 | kavieng
# Processing Record 41 of Set 9 | mweka
# Processing Record 42 of Set 9 | tolanaro
# Processing Record 43 of Set 9 | narrabri
# Processing Record 44 of Set 9 | shingu
# Processing Record 45 of Set 9 | leava
# Processing Record 46 of Set 9 | carbonear
# Processing Record 47 of Set 9 | igarka
# Processing Record 48 of Set 9 | argostolion
# Processing Record 49 of Set 9 | weno
# Processing Record 0 of Set 10 | nguigmi
# Processing Record 1 of Set 10 | saksaul'skiy
# City not found. Skipping...
# Processing Record 2 of Set 10 | gobabis
# Processing Record 3 of Set 10 | casino
# Processing Record 4 of Set 10 | khandyga
# Processing Record 5 of Set 10 | shache
# Processing Record 6 of Set 10 | winnemucca
# Processing Record 7 of Set 10 | arenapolis
# Processing Record 8 of Set 10 | uman
# Processing Record 9 of Set 10 | tipasa
# Processing Record 10 of Set 10 | anahuac
# Processing Record 11 of Set 10 | tiquipaya
# Processing Record 12 of Set 10 | arti
# Processing Record 13 of Set 10 | la foa
# Processing Record 14 of Set 10 | fonte boa
# Processing Record 15 of Set 10 | raipur
# Processing Record 16 of Set 10 | pandan
# Processing Record 17 of Set 10 | urangan
# Processing Record 18 of Set 10 | dubbo
# Processing Record 19 of Set 10 | semnan
# Processing Record 20 of Set 10 | chiredzi
# Processing Record 21 of Set 10 | nar'yan-mar
# Processing Record 22 of Set 10 | kuloy
# Processing Record 23 of Set 10 | paramonga
# Processing Record 24 of Set 10 | palenque
# Processing Record 25 of Set 10 | stephenville
# Processing Record 26 of Set 10 | gazojak
# Processing Record 27 of Set 10 | tomatlan
# Processing Record 28 of Set 10 | muroto-misakicho
# Processing Record 29 of Set 10 | kotabumi
# Processing Record 30 of Set 10 | hasaki
# Processing Record 31 of Set 10 | nolinsk
# Processing Record 32 of Set 10 | remire-montjoly
# Processing Record 33 of Set 10 | morro agudo
# Processing Record 34 of Set 10 | hansot
# Processing Record 35 of Set 10 | langsa
# Processing Record 36 of Set 10 | conceicao da barra
# Processing Record 37 of Set 10 | karasburg
# Processing Record 38 of Set 10 | kolokani
# Processing Record 39 of Set 10 | figuig (centre)
# Processing Record 40 of Set 10 | ko samui
# Processing Record 41 of Set 10 | kaitong
# Processing Record 42 of Set 10 | ulsteinvik
# Processing Record 43 of Set 10 | xinpu
# Processing Record 44 of Set 10 | juneau
# Processing Record 45 of Set 10 | el porvenir
# Processing Record 46 of Set 10 | vadso
# Processing Record 47 of Set 10 | kingston
# Processing Record 48 of Set 10 | bargara
# City not found. Skipping...
# Processing Record 49 of Set 10 | queenstown
# Processing Record 0 of Set 11 | loa janan
# Processing Record 1 of Set 11 | cassilandia
# Processing Record 2 of Set 11 | island harbour
# Processing Record 3 of Set 11 | sesheke
# Processing Record 4 of Set 11 | peniche
# Processing Record 5 of Set 11 | villa gesell
# Processing Record 6 of Set 11 | limulunga
# Processing Record 7 of Set 11 | manjo
# Processing Record 8 of Set 11 | vingt cinq
# City not found. Skipping...
# Processing Record 9 of Set 11 | sao joao batista
# Processing Record 10 of Set 11 | salalah
# Processing Record 11 of Set 11 | bowen
# Processing Record 12 of Set 11 | khilok
# Processing Record 13 of Set 11 | calp
# Processing Record 14 of Set 11 | praia da vitoria
# Processing Record 15 of Set 11 | assab
# Processing Record 16 of Set 11 | belle fourche
# Processing Record 17 of Set 11 | mae chai
# Processing Record 18 of Set 11 | le port
# Processing Record 19 of Set 11 | barnstaple
# Processing Record 20 of Set 11 | kismayo
# Processing Record 21 of Set 11 | zangguy
# City not found. Skipping...
# Processing Record 22 of Set 11 | dul'durga
# Processing Record 23 of Set 11 | nambucca heads
# Processing Record 24 of Set 11 | wakkanai
# Processing Record 25 of Set 11 | kanye
# Processing Record 26 of Set 11 | mancio lima
# Processing Record 27 of Set 11 | abu al matamir
# Processing Record 28 of Set 11 | saint-girons
# Processing Record 29 of Set 11 | albertina
# Processing Record 30 of Set 11 | afaahiti
# Processing Record 31 of Set 11 | coyhaique
# Processing Record 32 of Set 11 | phan rang-thap cham
# Processing Record 33 of Set 11 | mermoz boabab
# Processing Record 34 of Set 11 | sahaspur
# Processing Record 35 of Set 11 | asasa
# Processing Record 36 of Set 11 | gebeit
# Processing Record 37 of Set 11 | westport
# Processing Record 38 of Set 11 | mecca
# Processing Record 39 of Set 11 | guilmaro
# City not found. Skipping...
# Processing Record 40 of Set 11 | nanao
# Processing Record 41 of Set 11 | holualoa
# Processing Record 42 of Set 11 | puerto gaitan
# Processing Record 43 of Set 11 | siocon
# Processing Record 44 of Set 11 | cockburn town
# Processing Record 45 of Set 11 | ulaangom
# Processing Record 46 of Set 11 | luang namtha
# Processing Record 47 of Set 11 | mogoditshane
# Processing Record 48 of Set 11 | sola
# Processing Record 49 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 0 of Set 12 | wynyard
# Processing Record 1 of Set 12 | kerikeri
# Processing Record 2 of Set 12 | vila velha
# Processing Record 3 of Set 12 | stourport-on-severn
# Processing Record 4 of Set 12 | pokhara
# Processing Record 5 of Set 12 | salym
# Processing Record 6 of Set 12 | laojunmiao
# Processing Record 7 of Set 12 | dubna
# Processing Record 8 of Set 12 | greenville
# Processing Record 9 of Set 12 | nejo
# Processing Record 10 of Set 12 | koping
# Processing Record 11 of Set 12 | minna
# Processing Record 12 of Set 12 | luena
# Processing Record 13 of Set 12 | fannuj
# City not found. Skipping...
# Processing Record 14 of Set 12 | wotje
# Processing Record 15 of Set 12 | thabazimbi
# Processing Record 16 of Set 12 | inirida
# Processing Record 17 of Set 12 | blagoveshchenka
# Processing Record 18 of Set 12 | ouro preto do oeste
# Processing Record 19 of Set 12 | porto murtinho
# Processing Record 20 of Set 12 | awjilah
# Processing Record 21 of Set 12 | shangri-la
# City not found. Skipping...
# Processing Record 22 of Set 12 | achinsk
# Processing Record 23 of Set 12 | xilin hot
# Processing Record 24 of Set 12 | saldanha
# Processing Record 25 of Set 12 | we
# City not found. Skipping...
# Processing Record 26 of Set 12 | darovskoy
# Processing Record 27 of Set 12 | flekkefjord
# Processing Record 28 of Set 12 | masindi
# Processing Record 29 of Set 12 | aral
# Processing Record 30 of Set 12 | takeo
# Processing Record 31 of Set 12 | altay
# Processing Record 32 of Set 12 | salatiga
# Processing Record 33 of Set 12 | ciudad satelite
# Processing Record 34 of Set 12 | kyshtovka
# Processing Record 35 of Set 12 | vetluzhskiy
# Processing Record 36 of Set 12 | karratha
# Processing Record 37 of Set 12 | namtsy
# Processing Record 38 of Set 12 | lamarque
# Processing Record 39 of Set 12 | miarinarivo
# City not found. Skipping...
# Processing Record 40 of Set 12 | mildura
# Processing Record 41 of Set 12 | puerto armuelles
# Processing Record 42 of Set 12 | shevchenko
# Processing Record 43 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 44 of Set 12 | kristiansund
# Processing Record 45 of Set 12 | lagoa
# Processing Record 46 of Set 12 | tadine
# Processing Record 47 of Set 12 | ceeldheer
# Processing Record 48 of Set 12 | tvoroyri
# Processing Record 49 of Set 12 | santa ana de yacuma
# Processing Record 0 of Set 13 | antofagasta
# Processing Record 1 of Set 13 | pitomaca
# Processing Record 2 of Set 13 | mandal
# Processing Record 3 of Set 13 | plastun
# Processing Record 4 of Set 13 | ponte nova
# Processing Record 5 of Set 13 | moyale
# Processing Record 6 of Set 13 | port hedland
# Processing Record 7 of Set 13 | sabzevar
# Processing Record 8 of Set 13 | woodstock
# Processing Record 9 of Set 13 | venadillo
# Processing Record 10 of Set 13 | tonj
# Processing Record 11 of Set 13 | umm kaddadah
# Processing Record 12 of Set 13 | magadan
# Processing Record 13 of Set 13 | mujiayingzi
# Processing Record 14 of Set 13 | coyuca de catalan
# Processing Record 15 of Set 13 | mpanda
# Processing Record 16 of Set 13 | san sebastian de la gomera
# Processing Record 17 of Set 13 | merizo village
# Processing Record 18 of Set 13 | port douglas
# Processing Record 19 of Set 13 | maceio
# Processing Record 20 of Set 13 | cumaribo
# City not found. Skipping...
# Processing Record 21 of Set 13 | hanzhong
# Processing Record 22 of Set 13 | olivenza
# Processing Record 23 of Set 13 | vilhena
# Processing Record 24 of Set 13 | crane
# Processing Record 25 of Set 13 | christchurch
# Processing Record 26 of Set 13 | oualidia
# City not found. Skipping...
# Processing Record 27 of Set 13 | puerto quijarro
# Processing Record 28 of Set 13 | suifenhe
# Processing Record 29 of Set 13 | malyye derbety
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# # Convert the cities weather data into a Pandas DataFrame
# city_data_df = pd.DataFrame({
#     "City": cities,
#     "Lat": city_lat,
#     "Lng": city_lng,
#     "Max Temp": city_max_temp,
#     "Humidity": city_humidity,
#     "Cloudiness": city_clouds,
#     "Wind": city_wind,
#     "Country": city_country,
#     "Date": city_date,
    
    
# })

# #Drop any cities that were skipped in the previous response
# city_data_df = city_data_df.dropna(how="any")

# # Show Record Count
# city_data_df.count()
# Out:
# City          630
# Lat           630
# Lng           630
# Max Temp      630
# Humidity      630
# Cloudiness    630
# Wind          630
# Country       630
# Date          630
# dtype: int64

# %%
# # Display sample data
# city_data_df.head()
# Out:
#                City      Lat      Lng  Max Temp  Humidity  Cloudiness  Wind  \
# 0        isafjordur  47.9547  44.6808     78.91        43           0  4.09
# 1          thompson  47.9547  44.6808     78.91        43           0  4.09
# 2           ushuaia  47.9547  44.6808     78.91        43           0  4.09
# 3  zumpango del rio  47.9547  44.6808     78.91        43           0  4.09
# 4          coquimbo  47.9547  44.6808     78.91        43           0  4.09
#
#   Country        Date
# 0      RU  1690427592
# 1      RU  1690427592
# 2      RU  1690427592
# 3      RU  1690427592
# 4      RU  1690427592

# %%
# # Export the City_Data into a csv
# city_data_df.to_csv("./output_data/cities.csv", index_label="City_ID")

# %%
# # Read saved data
# city_data_df = pd.read_csv("./output_data/cities.csv", index_col="City_ID")

# # Display sample data
# city_data_df.head()
# Out:
#                       City   Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                 hamilton -17.8 -63.1667     68.05        60          75
# 1        port-aux-francais -17.8 -63.1667     68.05        60          75
# 2              thohoyandou -17.8 -63.1667     68.05        60          75
# 3            port mathurin -17.8 -63.1667     68.05        60          75
# 4                  iqaluit -17.8 -63.1667     68.05        60          75
#
#           Wind Country        Date
# City_ID
# 0        12.66      BO  1690413678
# 1        12.66      BO  1690413678
# 2        12.66      BO  1690413678
# 3        12.66      BO  1690413678
# 4        12.66      BO  1690413678

# %%
city_data_df = pd.DataFrame(city_data)

city_data_df.count()
# Out:
# City          600
# Lat           600
# Lng           600
# Max Temp      600
# Humidity      600
# Cloudiness    600
# Wind Speed    600
# Country       600
# Date          600
# dtype: int64

# %%
city_data_df.head()
# Out:
#                City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0        isafjordur  66.0755 -23.1240     44.33        88          98
# 1          thompson  55.7435 -97.8558     57.36        82         100
# 2           ushuaia -54.8000 -68.3000     31.66        69           0
# 3  zumpango del rio  17.6500 -99.5000     67.73        90          42
# 4          coquimbo -29.9533 -71.3436     55.13        87           0
#
#    Wind Speed Country        Date
# 0       11.83      IS  1690426565
# 1        2.30      CA  1690426565
# 2        5.75      AR  1690426566
# 3        3.80      MX  1690426567
# 4        4.61      CL  1690426567

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# date_now = datetime.date(datetime.now())

x_values = city_data_df["Lat"]
y_values = city_data_df["Max Temp"]

fig1, ax1 = plt.subplots(figsize=(8,5))

# Incorporate the other graph properties
plt.scatter(x_values, y_values, edgecolor="black", linewidth=.75, marker="o", alpha=0.8)
plt.title(f"City Max Latitude vs Temperature (2022-10-18)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()
          

# Save the figure
plt.savefig("./output_data/latitude_vs_max_temp.png", bbox_inches="tight")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x_values = city_data_df["Lat"]
y_values = city_data_df["Humidity"]

fig1, ax1 = plt.subplots(figsize=(11,8))

# Incorporate the other graph properties
plt.scatter(x_values, y_values, edgecolor="black", linewidth=.75, marker="o", alpha=0.8)
plt.title(f"City Latitude vs Humidity (2022-10-18)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()
          

# Save the figure
plt.savefig("./output_data/latitude_vs_humidity.png", bbox_inches="tight")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x_values = city_data_df["Lat"]
y_values = city_data_df["Cloudiness"]

fig1, ax1 = plt.subplots(figsize=(12,8))

# Incorporate the other graph properties

plt.scatter(x_values, y_values, edgecolor="black", linewidth=.75, marker="o", alpha=0.8)
plt.title(f"City Max Latitude vs Cloudiness (2022-10-18)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
          

# Save the figure
plt.savefig("./output_data/latitude_vs_cloudiness.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
x_values = city_data_df["Lat"]
y_values = city_data_df["Wind Speed"]

fig1, ax1 = plt.subplots(figsize=(11,8))

# Incorporate the other graph properties
plt.scatter(x_values, y_values, edgecolor="black", linewidth=.75, marker="o", alpha=0.8)
plt.title(f"City Latitude vs Wind Speed (2022-10-18)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid()
          

# Save the figure
plt.savefig("./output_data/latitude_vs_wind_speed.png", bbox_inches="tight")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, x_label, y_label, hemisphere, text_coordinates, ylim=None):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

    # Get regression values
    regress_values = x_values * slope + intercept
    
    # Create line equation string
    line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
    
    # Generate plots     
    fig1, ax1 = plt.subplots(figsize=(12,8))
    plt.scatter(x_values, y_values, edgecolor="black", linewidth=1, marker="o", alpha=0.8)
    plt.plot(x_values,regress_values,"r-")
    
    # Add in labels 
    plt.title(f"{hemisphere} Hemisphere - {x_label} vs {y_label}",fontsize = 15)
    plt.xlabel(x_label,fontsize=14)
    plt.ylabel(y_label,fontsize=14)
    
    if ylim is not None:
        plt.ylim(0, ylim)
    plt.annotate(line_eq, text_coordinates, fontsize=20, color="red")
    
    # Print r square value
    print(f"The r-squared is: {rvalue**2}")
    correlation = st.pearsonr(x_values,y_values)
    print(f"The correlation between both factors is {round(correlation[0],2)}")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0        isafjordur  66.0755 -23.1240     44.33        88          98
# 1          thompson  55.7435 -97.8558     57.36        82         100
# 3  zumpango del rio  17.6500 -99.5000     67.73        90          42
# 7              argo  37.6333  22.7333     84.78        58           0
# 9         kavaratti  10.5669  72.6420     82.63        73         100
#
#    Wind Speed Country        Date
# 0       11.83      IS  1690426565
# 1        2.30      CA  1690426565
# 3        3.80      MX  1690426567
# 7        5.03      GR  1690426568
# 9       13.49      IN  1690426569

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 2        ushuaia -54.8000  -68.3000     31.66        69           0
# 4       coquimbo -29.9533  -71.3436     55.13        87           0
# 5     codrington -38.2667  141.9667     59.56        63           2
# 6          moree -29.4667  149.8500     67.69        44           0
# 8  blackmans bay -43.0167  147.3167     56.73        68         100
#
#    Wind Speed Country        Date
# 2        5.75      AR  1690426566
# 4        4.61      CL  1690426567
# 5       17.96      AU  1690426567
# 6        5.26      AU  1690426568
# 8        4.74      AU  1690426568

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Latitude", "Max Temp", "Northern", (10, 10))

# Save the output to png
plt.savefig("./output_data/northern_linear_lat_vs_max_temp.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.2956117073769424
# The correlation between both factors is -0.54

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Latitude", "Max Temp (F)", "Southern", (10, 10))

# Save the output to png
plt.savefig("./output_data/southern_linear_lat_vs_max_temp.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.5920311808548367
# The correlation between both factors is 0.77

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']

# Plot the linear regression and save r value
plot_linear_regression(x_values, y_values, "Latitude", "Humidity (%)", "Northern",(50,50))

# Save the output to png
plt.savefig("./output_data/northern_linear_lat_vs_humidity.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.0014868547905884668
# The correlation between both factors is -0.04

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']

# Plot the regression, calculate r value
plot_linear_regression(x_values, y_values, "Latitude", "Humidity (%)", "Southern",(50, 50), 100)

# Save the output as png
plt.savefig("./output_data/southern_linear_lat_vs_humudity.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.0034689903904610913
# The correlation between both factors is -0.06

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']
plot_linear_regression(x_values, y_values, "Latitude", "Cloudiness (%)", "Northern", (20, 60))

plt.savefig("./output_data/northern_linear_lat_vs_cloudiness.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.021919252171645663
# The correlation between both factors is -0.15

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']
plot_linear_regression(x_values, y_values, "Latitude", "Cloudiness (%)", "Southern", (20, 60))

plt.savefig("./output_data/southern_linear_lat_vs_cloudiness.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.0037165419115388863
# The correlation between both factors is -0.06

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']

# Plot linear regression and calculate r value
plot_linear_regression(x_values, y_values, "Latitude", "Wind Speed (mph)", "Northern",(20, 25))

# Save the scatterplot as png
plt.savefig("./output_data/northern_linear_lat_vs_wind_speed.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.024132808705232347
# The correlation between both factors is -0.16

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']

# Plot linear regression and calculate r value
plot_linear_regression(x_values, y_values, "Latitude", "Wind Speed (mph)", "Southern",(20, 25))

# Save the scatterplot as png
plt.savefig("./output_data/southern_linear_lat_vs_wind_speed.png", bbox_inches="tight")
plt.show()
# Out:
# The r-squared is: 0.0209843399343203
# The correlation between both factors is -0.14

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
