# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from datetime import datetime
from scipy.stats import linregress

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# Create output file
output_file = "output_data/cities.csv"

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 632

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# Define an empty list to fetch the weather data for each city
city_data = []
coord = []
lat = []
lng = []
temp = []
max_temp = []
humidity = []
clouds = []
wind = []
country = []
date = []


# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0
        time.sleep(60)

    # Create endpoint URL with each city
    city_url = query_url = f"{url}appid={weather_api_key}&units={units}&q="
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(query_url + city).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    #If an error is experienced, skip the city
    except KeyError:
        print("City not found. Skipping...")

        pass
              
# Indicate that Data Loading is complete 

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nova sintra
# Processing Record 2 of Set 1 | adamstown
# Processing Record 3 of Set 1 | lihue
# Processing Record 4 of Set 1 | port-aux-francais
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | lobujya
# Processing Record 7 of Set 1 | bethel
# Processing Record 8 of Set 1 | grytviken
# Processing Record 9 of Set 1 | port moresby
# Processing Record 10 of Set 1 | coahuayana de hidalgo
# Processing Record 11 of Set 1 | cozumel
# Processing Record 12 of Set 1 | margate
# Processing Record 13 of Set 1 | ingeniero guillermo n. juarez
# Processing Record 14 of Set 1 | puerto natales
# Processing Record 15 of Set 1 | jamestown
# Processing Record 16 of Set 1 | fort st. john
# Processing Record 17 of Set 1 | iqaluit
# Processing Record 18 of Set 1 | hawaiian paradise park
# Processing Record 19 of Set 1 | fortuna
# Processing Record 20 of Set 1 | jasper
# Processing Record 21 of Set 1 | usinsk
# Processing Record 22 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 23 of Set 1 | buala
# Processing Record 24 of Set 1 | invercargill
# Processing Record 25 of Set 1 | port lincoln
# Processing Record 26 of Set 1 | papatowai
# Processing Record 27 of Set 1 | tromso
# Processing Record 28 of Set 1 | hobyo
# Processing Record 29 of Set 1 | anadyr
# Processing Record 30 of Set 1 | constantia
# Processing Record 31 of Set 1 | san antonio de pale
# Processing Record 32 of Set 1 | coquimbo
# Processing Record 33 of Set 1 | tranovaho
# City not found. Skipping...
# Processing Record 34 of Set 1 | starodub
# Processing Record 35 of Set 1 | huarmey
# Processing Record 36 of Set 1 | happy valley-goose bay
# Processing Record 37 of Set 1 | tazovsky
# Processing Record 38 of Set 1 | piti village
# Processing Record 39 of Set 1 | maragogi
# Processing Record 40 of Set 1 | port elizabeth
# Processing Record 41 of Set 1 | blackmans bay
# Processing Record 42 of Set 1 | waitangi
# Processing Record 43 of Set 1 | naze
# Processing Record 44 of Set 1 | unye
# City not found. Skipping...
# Processing Record 45 of Set 1 | lebu
# Processing Record 46 of Set 1 | al jawf
# Processing Record 47 of Set 1 | namie
# Processing Record 48 of Set 1 | chios
# Processing Record 49 of Set 1 | albany
# Processing Record 50 of Set 1 | thompson
# Processing Record 0 of Set 2 | vi thanh
# City not found. Skipping...
# Processing Record 1 of Set 2 | kijang
# Processing Record 2 of Set 2 | kodiak
# Processing Record 3 of Set 2 | enewetak
# Processing Record 4 of Set 2 | porto novo
# Processing Record 5 of Set 2 | shalqar
# Processing Record 6 of Set 2 | edinburgh of the seven seas
# Processing Record 7 of Set 2 | east ballina
# Processing Record 8 of Set 2 | lompoc
# Processing Record 9 of Set 2 | bilibino
# Processing Record 10 of Set 2 | portland
# Processing Record 11 of Set 2 | newman
# Processing Record 12 of Set 2 | longyearbyen
# Processing Record 13 of Set 2 | adigrat
# Processing Record 14 of Set 2 | ust-nera
# Processing Record 15 of Set 2 | limuru
# Processing Record 16 of Set 2 | grand falls-windsor
# Processing Record 17 of Set 2 | vila franca do campo
# Processing Record 18 of Set 2 | atafu village
# Processing Record 19 of Set 2 | vila velha
# Processing Record 20 of Set 2 | les cayes
# Processing Record 21 of Set 2 | arroyo
# Processing Record 22 of Set 2 | georgetown
# Processing Record 23 of Set 2 | antsiranana
# Processing Record 24 of Set 2 | kyren
# Processing Record 25 of Set 2 | sidqabad
# City not found. Skipping...
# Processing Record 26 of Set 2 | vreden
# Processing Record 27 of Set 2 | susuman
# Processing Record 28 of Set 2 | ujae
# Processing Record 29 of Set 2 | isafjordur
# Processing Record 30 of Set 2 | palmer
# Processing Record 31 of Set 2 | zitlaltepec
# Processing Record 32 of Set 2 | kuta
# Processing Record 33 of Set 2 | ta`u
# Processing Record 34 of Set 2 | talcahuano
# Processing Record 35 of Set 2 | choctaw
# Processing Record 36 of Set 2 | badger
# Processing Record 37 of Set 2 | monroe
# Processing Record 38 of Set 2 | mount isa
# Processing Record 39 of Set 2 | lubumbashi
# Processing Record 40 of Set 2 | afaahiti
# Processing Record 41 of Set 2 | south hedland
# Processing Record 42 of Set 2 | tiksi
# Processing Record 43 of Set 2 | teknaf
# Processing Record 44 of Set 2 | ribeira grande
# Processing Record 45 of Set 2 | ha'il
# Processing Record 46 of Set 2 | vorgashor
# Processing Record 47 of Set 2 | arkhangel'sk
# Processing Record 48 of Set 2 | rostovka
# Processing Record 49 of Set 2 | lazaro cardenas
# Processing Record 0 of Set 3 | oamaru
# Processing Record 1 of Set 3 | fale old settlement
# Processing Record 2 of Set 3 | pathein
# Processing Record 3 of Set 3 | college
# Processing Record 4 of Set 3 | altai
# Processing Record 5 of Set 3 | rebrikha
# Processing Record 6 of Set 3 | cooper's town
# Processing Record 7 of Set 3 | wailua homesteads
# Processing Record 8 of Set 3 | gunnedah
# Processing Record 9 of Set 3 | nyzhni sirohozy
# Processing Record 10 of Set 3 | qaqortoq
# Processing Record 11 of Set 3 | saudarkrokur
# Processing Record 12 of Set 3 | dudinka
# Processing Record 13 of Set 3 | bakanas
# Processing Record 14 of Set 3 | kalevala
# Processing Record 15 of Set 3 | yellowknife
# Processing Record 16 of Set 3 | kristiansund
# Processing Record 17 of Set 3 | carnarvon
# Processing Record 18 of Set 3 | zarghun shahr
# Processing Record 19 of Set 3 | tinghir
# Processing Record 20 of Set 3 | nuuk
# Processing Record 21 of Set 3 | mount gambier
# Processing Record 22 of Set 3 | west island
# Processing Record 23 of Set 3 | alofi
# Processing Record 24 of Set 3 | khandyga
# Processing Record 25 of Set 3 | arraial do cabo
# Processing Record 26 of Set 3 | totana
# Processing Record 27 of Set 3 | porto belo
# Processing Record 28 of Set 3 | kupang
# Processing Record 29 of Set 3 | mitsamiouli
# Processing Record 30 of Set 3 | tangalle
# Processing Record 31 of Set 3 | okakarara
# Processing Record 32 of Set 3 | flin flon
# Processing Record 33 of Set 3 | keflavik
# Processing Record 34 of Set 3 | popondetta
# Processing Record 35 of Set 3 | crane
# Processing Record 36 of Set 3 | nemuro
# Processing Record 37 of Set 3 | papao
# Processing Record 38 of Set 3 | lisala
# Processing Record 39 of Set 3 | williams lake
# Processing Record 40 of Set 3 | bathsheba
# Processing Record 41 of Set 3 | jijel
# Processing Record 42 of Set 3 | tindouf
# Processing Record 43 of Set 3 | talnakh
# Processing Record 44 of Set 3 | santa ana
# Processing Record 45 of Set 3 | bredasdorp
# Processing Record 46 of Set 3 | dubbo
# Processing Record 47 of Set 3 | vingt cinq
# City not found. Skipping...
# Processing Record 48 of Set 3 | olonkinbyen
# Processing Record 49 of Set 3 | kruisfontein
# Processing Record 0 of Set 4 | whitehorse
# Processing Record 1 of Set 4 | timimoun
# Processing Record 2 of Set 4 | dhuusamarreeb
# Processing Record 3 of Set 4 | geraldton
# Processing Record 4 of Set 4 | espita
# Processing Record 5 of Set 4 | puerto baquerizo moreno
# Processing Record 6 of Set 4 | saint-quentin
# Processing Record 7 of Set 4 | cumaribo
# City not found. Skipping...
# Processing Record 8 of Set 4 | aasiaat
# Processing Record 9 of Set 4 | port alfred
# Processing Record 10 of Set 4 | kimbe
# Processing Record 11 of Set 4 | jiuquan
# Processing Record 12 of Set 4 | hamilton
# Processing Record 13 of Set 4 | basoda
# Processing Record 14 of Set 4 | belyy yar
# Processing Record 15 of Set 4 | steyr
# Processing Record 16 of Set 4 | kerema
# Processing Record 17 of Set 4 | yakeshi
# Processing Record 18 of Set 4 | la passe
# Processing Record 19 of Set 4 | east london
# Processing Record 20 of Set 4 | nar'yan-mar
# Processing Record 21 of Set 4 | zag
# Processing Record 22 of Set 4 | la'ie
# Processing Record 23 of Set 4 | turpan
# Processing Record 24 of Set 4 | thunder bay
# Processing Record 25 of Set 4 | kamyshevatskaya
# Processing Record 26 of Set 4 | dalianwan
# Processing Record 27 of Set 4 | pacific grove
# Processing Record 28 of Set 4 | buzuluk
# Processing Record 29 of Set 4 | fuvahmulah
# City not found. Skipping...
# Processing Record 30 of Set 4 | mejit
# Processing Record 31 of Set 4 | morrinhos
# Processing Record 32 of Set 4 | puerto ayora
# Processing Record 33 of Set 4 | yeppoon
# Processing Record 34 of Set 4 | el matama
# Processing Record 35 of Set 4 | arar
# Processing Record 36 of Set 4 | yarim
# Processing Record 37 of Set 4 | ilulissat
# Processing Record 38 of Set 4 | ataq
# Processing Record 39 of Set 4 | la sarre
# Processing Record 40 of Set 4 | johi
# Processing Record 41 of Set 4 | gambiran satu
# Processing Record 42 of Set 4 | domna
# Processing Record 43 of Set 4 | cold springs
# Processing Record 44 of Set 4 | solnechnyy
# Processing Record 45 of Set 4 | ust'-kut
# Processing Record 46 of Set 4 | ulsteinvik
# Processing Record 47 of Set 4 | szczawnica
# Processing Record 48 of Set 4 | lionel town
# Processing Record 49 of Set 4 | waddan
# Processing Record 0 of Set 5 | ariyalur
# Processing Record 1 of Set 5 | luderitz
# Processing Record 2 of Set 5 | hermanus
# Processing Record 3 of Set 5 | kinablangan
# Processing Record 4 of Set 5 | buabidi
# City not found. Skipping...
# Processing Record 5 of Set 5 | saipan
# Processing Record 6 of Set 5 | praia da vitoria
# Processing Record 7 of Set 5 | gamba
# Processing Record 8 of Set 5 | ratnagiri
# Processing Record 9 of Set 5 | dongcun
# Processing Record 10 of Set 5 | al ghayzah
# Processing Record 11 of Set 5 | fukuecho
# Processing Record 12 of Set 5 | awjilah
# Processing Record 13 of Set 5 | bridgetown
# Processing Record 14 of Set 5 | saint-philippe
# Processing Record 15 of Set 5 | suntar
# Processing Record 16 of Set 5 | stanley
# Processing Record 17 of Set 5 | foumban
# Processing Record 18 of Set 5 | igarka
# Processing Record 19 of Set 5 | cargados carajos
# City not found. Skipping...
# Processing Record 20 of Set 5 | fuglafjordur
# Processing Record 21 of Set 5 | ondjiva
# Processing Record 22 of Set 5 | sompeta
# Processing Record 23 of Set 5 | weno
# Processing Record 24 of Set 5 | guerrero negro
# Processing Record 25 of Set 5 | kidal
# Processing Record 26 of Set 5 | itacoatiara
# Processing Record 27 of Set 5 | port isabel
# Processing Record 28 of Set 5 | arroio grande
# Processing Record 29 of Set 5 | kangding
# Processing Record 30 of Set 5 | palu
# Processing Record 31 of Set 5 | chillan
# Processing Record 32 of Set 5 | nantucket
# Processing Record 33 of Set 5 | kayangel
# Processing Record 34 of Set 5 | sarangani
# Processing Record 35 of Set 5 | kuqa
# Processing Record 36 of Set 5 | luanda
# Processing Record 37 of Set 5 | kirakira
# Processing Record 38 of Set 5 | haiku-pauwela
# Processing Record 39 of Set 5 | krasnoarmeyskaya
# Processing Record 40 of Set 5 | colonia
# Processing Record 41 of Set 5 | santa marta de ortigueira
# Processing Record 42 of Set 5 | sal rei
# Processing Record 43 of Set 5 | mili
# Processing Record 44 of Set 5 | namtsy
# Processing Record 45 of Set 5 | badiyah
# Processing Record 46 of Set 5 | margaret river
# Processing Record 47 of Set 5 | howrah
# Processing Record 48 of Set 5 | avarua
# Processing Record 49 of Set 5 | flying fish cove
# Processing Record 0 of Set 6 | mancio lima
# Processing Record 1 of Set 6 | baishishan
# Processing Record 2 of Set 6 | berdigestyakh
# Processing Record 3 of Set 6 | pangody
# Processing Record 4 of Set 6 | ambovombe
# Processing Record 5 of Set 6 | sonsorol village
# City not found. Skipping...
# Processing Record 6 of Set 6 | domoni
# Processing Record 7 of Set 6 | baciu
# Processing Record 8 of Set 6 | mstsislaw
# Processing Record 9 of Set 6 | ed damer
# Processing Record 10 of Set 6 | marquette
# Processing Record 11 of Set 6 | luocheng
# Processing Record 12 of Set 6 | yashkul'
# Processing Record 13 of Set 6 | cifteler
# Processing Record 14 of Set 6 | hinis
# Processing Record 15 of Set 6 | synel'nykove
# Processing Record 16 of Set 6 | mogocha
# Processing Record 17 of Set 6 | miyanoura
# City not found. Skipping...
# Processing Record 18 of Set 6 | ad dindar
# Processing Record 19 of Set 6 | krasnaya polyana
# Processing Record 20 of Set 6 | dukhan
# Processing Record 21 of Set 6 | yuzhno-kurilsk
# Processing Record 22 of Set 6 | cabo san lucas
# Processing Record 23 of Set 6 | matam
# Processing Record 24 of Set 6 | prado
# Processing Record 25 of Set 6 | tsiolkovskiy
# City not found. Skipping...
# Processing Record 26 of Set 6 | leck
# Processing Record 27 of Set 6 | mount pearl
# Processing Record 28 of Set 6 | rio gallegos
# Processing Record 29 of Set 6 | nikolayevsk-on-amure
# Processing Record 30 of Set 6 | petropavlovsk-kamchatsky
# Processing Record 31 of Set 6 | abay
# Processing Record 32 of Set 6 | howard springs
# Processing Record 33 of Set 6 | hithadhoo
# Processing Record 34 of Set 6 | ocean shores
# Processing Record 35 of Set 6 | razole
# Processing Record 36 of Set 6 | chonchi
# Processing Record 37 of Set 6 | barda
# Processing Record 38 of Set 6 | pervomayskoye
# Processing Record 39 of Set 6 | port mathurin
# Processing Record 40 of Set 6 | christchurch
# Processing Record 41 of Set 6 | codrington
# Processing Record 42 of Set 6 | ribeira brava
# Processing Record 43 of Set 6 | sola
# Processing Record 44 of Set 6 | fauske
# Processing Record 45 of Set 6 | sao jose da coroa grande
# Processing Record 46 of Set 6 | udachny
# Processing Record 47 of Set 6 | tura
# Processing Record 48 of Set 6 | puerto san carlos
# City not found. Skipping...
# Processing Record 49 of Set 6 | pisco
# Processing Record 0 of Set 7 | ola
# Processing Record 1 of Set 7 | qoryooley
# Processing Record 2 of Set 7 | carauari
# Processing Record 3 of Set 7 | punta arenas
# Processing Record 4 of Set 7 | rikaze
# Processing Record 5 of Set 7 | bonthe
# Processing Record 6 of Set 7 | okhotsk
# Processing Record 7 of Set 7 | ancud
# Processing Record 8 of Set 7 | phalaborwa
# Processing Record 9 of Set 7 | kawthoung
# City not found. Skipping...
# Processing Record 10 of Set 7 | karratha
# Processing Record 11 of Set 7 | utrik
# Processing Record 12 of Set 7 | banamba
# Processing Record 13 of Set 7 | revda
# Processing Record 14 of Set 7 | northam
# Processing Record 15 of Set 7 | kapa'a
# Processing Record 16 of Set 7 | aguilar de campoo
# Processing Record 17 of Set 7 | kailua-kona
# Processing Record 18 of Set 7 | klyuchi
# Processing Record 19 of Set 7 | mbanza-ngungu
# Processing Record 20 of Set 7 | ouallam
# Processing Record 21 of Set 7 | kovdor
# Processing Record 22 of Set 7 | gaoping
# Processing Record 23 of Set 7 | aoulef
# Processing Record 24 of Set 7 | wegorzewo
# Processing Record 25 of Set 7 | bathurst
# Processing Record 26 of Set 7 | edd
# Processing Record 27 of Set 7 | callao
# Processing Record 28 of Set 7 | sitka
# Processing Record 29 of Set 7 | sandnessjoen
# Processing Record 30 of Set 7 | touros
# Processing Record 31 of Set 7 | farafangana
# Processing Record 32 of Set 7 | madalena
# Processing Record 33 of Set 7 | antonio enes
# Processing Record 34 of Set 7 | tongliao
# Processing Record 35 of Set 7 | charters towers
# Processing Record 36 of Set 7 | cidreira
# Processing Record 37 of Set 7 | porto-vecchio
# Processing Record 38 of Set 7 | atar
# Processing Record 39 of Set 7 | tiassale
# Processing Record 40 of Set 7 | nkurenkuru
# City not found. Skipping...
# Processing Record 41 of Set 7 | inhambane
# Processing Record 42 of Set 7 | ishigaki
# Processing Record 43 of Set 7 | greenville
# Processing Record 44 of Set 7 | qamdo
# Processing Record 45 of Set 7 | urbano santos
# Processing Record 46 of Set 7 | kingston
# Processing Record 47 of Set 7 | qeshm
# Processing Record 48 of Set 7 | strelka
# Processing Record 49 of Set 7 | mariara
# Processing Record 0 of Set 8 | mawu
# Processing Record 1 of Set 8 | san juan de miraflores
# Processing Record 2 of Set 8 | riberalta
# Processing Record 3 of Set 8 | ghat
# Processing Record 4 of Set 8 | vernon
# Processing Record 5 of Set 8 | chulym
# Processing Record 6 of Set 8 | arawa
# Processing Record 7 of Set 8 | zaysan
# Processing Record 8 of Set 8 | south grafton
# Processing Record 9 of Set 8 | ceeldheer
# Processing Record 10 of Set 8 | alice springs
# Processing Record 11 of Set 8 | male
# Processing Record 12 of Set 8 | la mira
# Processing Record 13 of Set 8 | hedaru
# Processing Record 14 of Set 8 | rio grande
# Processing Record 15 of Set 8 | opuwo
# Processing Record 16 of Set 8 | mirny
# Processing Record 17 of Set 8 | las heras
# Processing Record 18 of Set 8 | ilha de mocambique
# Processing Record 19 of Set 8 | alenquer
# Processing Record 20 of Set 8 | solikamsk
# Processing Record 21 of Set 8 | aliveri
# Processing Record 22 of Set 8 | tanjungbalai
# Processing Record 23 of Set 8 | preobrazheniye
# Processing Record 24 of Set 8 | sanctuary point
# Processing Record 25 of Set 8 | wakkanai
# Processing Record 26 of Set 8 | vadso
# Processing Record 27 of Set 8 | irymple
# Processing Record 28 of Set 8 | guatrache
# Processing Record 29 of Set 8 | hasaki
# Processing Record 30 of Set 8 | uturoa
# Processing Record 31 of Set 8 | brisas de zicatela
# Processing Record 32 of Set 8 | chui
# Processing Record 33 of Set 8 | monrovia
# Processing Record 34 of Set 8 | el granada
# Processing Record 35 of Set 8 | moapa valley
# Processing Record 36 of Set 8 | port saint john's
# Processing Record 37 of Set 8 | remire-montjoly
# Processing Record 38 of Set 8 | quatre cocos
# Processing Record 39 of Set 8 | statesville
# Processing Record 40 of Set 8 | calolbon
# Processing Record 41 of Set 8 | pemangkat
# Processing Record 42 of Set 8 | belozersk
# Processing Record 43 of Set 8 | camana
# Processing Record 44 of Set 8 | arteche
# Processing Record 45 of Set 8 | burutu
# Processing Record 46 of Set 8 | prainha
# Processing Record 47 of Set 8 | zouerate
# Processing Record 48 of Set 8 | nur-sultan
# Processing Record 49 of Set 8 | taitung city
# Processing Record 0 of Set 9 | saint-joseph
# Processing Record 1 of Set 9 | labytnangi
# Processing Record 2 of Set 9 | olutanga
# Processing Record 3 of Set 9 | tual
# Processing Record 4 of Set 9 | saiha
# Processing Record 5 of Set 9 | gadzhiyevo
# Processing Record 6 of Set 9 | lorengau
# Processing Record 7 of Set 9 | mount pleasant
# Processing Record 8 of Set 9 | krasnyy chikoy
# Processing Record 9 of Set 9 | celestun
# Processing Record 10 of Set 9 | villa gesell
# Processing Record 11 of Set 9 | novodvinsk
# Processing Record 12 of Set 9 | lensk
# Processing Record 13 of Set 9 | forster
# Processing Record 14 of Set 9 | chibougamau
# Processing Record 15 of Set 9 | rawlins
# Processing Record 16 of Set 9 | agara
# Processing Record 17 of Set 9 | grabouw
# Processing Record 18 of Set 9 | iskateley
# Processing Record 19 of Set 9 | puerto deseado
# Processing Record 20 of Set 9 | kenai
# Processing Record 21 of Set 9 | finley
# Processing Record 22 of Set 9 | barra de santo antonio
# Processing Record 23 of Set 9 | acarau
# Processing Record 24 of Set 9 | santa cruz
# Processing Record 25 of Set 9 | de witt
# Processing Record 26 of Set 9 | amurzet
# Processing Record 27 of Set 9 | nadym
# Processing Record 28 of Set 9 | new norfolk
# Processing Record 29 of Set 9 | bodrum
# Processing Record 30 of Set 9 | xiongzhou
# Processing Record 31 of Set 9 | chikhli
# Processing Record 32 of Set 9 | pandan
# Processing Record 33 of Set 9 | signal mountain
# Processing Record 34 of Set 9 | motueka
# Processing Record 35 of Set 9 | dhidhdhoo
# Processing Record 36 of Set 9 | haapajarvi
# Processing Record 37 of Set 9 | vilyuchinsk
# Processing Record 38 of Set 9 | manggar
# Processing Record 39 of Set 9 | griffith
# Processing Record 40 of Set 9 | conception bay south
# Processing Record 41 of Set 9 | morehead city
# Processing Record 42 of Set 9 | takamaka
# City not found. Skipping...
# Processing Record 43 of Set 9 | neryungri
# Processing Record 44 of Set 9 | itaituba
# Processing Record 45 of Set 9 | kulia village
# City not found. Skipping...
# Processing Record 46 of Set 9 | fortaleza
# Processing Record 47 of Set 9 | lembeni
# Processing Record 48 of Set 9 | taoudenni
# Processing Record 49 of Set 9 | polyarnyy
# Processing Record 0 of Set 10 | eichstatt
# Processing Record 1 of Set 10 | yarmouth
# Processing Record 2 of Set 10 | marsh harbour
# Processing Record 3 of Set 10 | zacualtipan
# Processing Record 4 of Set 10 | novyy urgal
# Processing Record 5 of Set 10 | mpika
# Processing Record 6 of Set 10 | devinuwara
# City not found. Skipping...
# Processing Record 7 of Set 10 | bardai
# Processing Record 8 of Set 10 | olyokminsk
# Processing Record 9 of Set 10 | holualoa
# Processing Record 10 of Set 10 | suomussalmi
# Processing Record 11 of Set 10 | erdenet
# Processing Record 12 of Set 10 | glace bay
# Processing Record 13 of Set 10 | taroa
# Processing Record 14 of Set 10 | magadan
# Processing Record 15 of Set 10 | dunedin
# Processing Record 16 of Set 10 | san borja
# Processing Record 17 of Set 10 | taro
# Processing Record 18 of Set 10 | sovetskiy
# Processing Record 19 of Set 10 | palmwoods
# Processing Record 20 of Set 10 | 'ohonua
# City not found. Skipping...
# Processing Record 21 of Set 10 | sulya
# Processing Record 22 of Set 10 | mandalgovi
# Processing Record 23 of Set 10 | cable beach
# City not found. Skipping...
# Processing Record 24 of Set 10 | masindi
# Processing Record 25 of Set 10 | kotido
# Processing Record 26 of Set 10 | tofol
# Processing Record 27 of Set 10 | pavilosta
# Processing Record 28 of Set 10 | sao vicente
# Processing Record 29 of Set 10 | shangri-la
# City not found. Skipping...
# Processing Record 30 of Set 10 | yazd
# Processing Record 31 of Set 10 | arambagh
# Processing Record 32 of Set 10 | st. john's
# Processing Record 33 of Set 10 | amga
# Processing Record 34 of Set 10 | beidao
# Processing Record 35 of Set 10 | sarkand
# Processing Record 36 of Set 10 | la ronge
# Processing Record 37 of Set 10 | prince rupert
# Processing Record 38 of Set 10 | mahibadhoo
# Processing Record 39 of Set 10 | rozhyshche
# Processing Record 40 of Set 10 | marka
# Processing Record 41 of Set 10 | charleston
# Processing Record 42 of Set 10 | keyes
# Processing Record 43 of Set 10 | fort bragg
# Processing Record 44 of Set 10 | wau
# Processing Record 45 of Set 10 | greymouth
# Processing Record 46 of Set 10 | kavaratti
# Processing Record 47 of Set 10 | kittila
# Processing Record 48 of Set 10 | aykhal
# Processing Record 49 of Set 10 | lebanon
# Processing Record 0 of Set 11 | sinabang
# Processing Record 1 of Set 11 | tarko-sale
# Processing Record 2 of Set 11 | wynyard
# Processing Record 3 of Set 11 | i-n-salah
# Processing Record 4 of Set 11 | mbeya
# Processing Record 5 of Set 11 | mopti
# Processing Record 6 of Set 11 | ulladulla
# Processing Record 7 of Set 11 | dryden
# Processing Record 8 of Set 11 | mongagua
# Processing Record 9 of Set 11 | castlegar
# Processing Record 10 of Set 11 | savanna-la-mar
# Processing Record 11 of Set 11 | el gouna
# Processing Record 12 of Set 11 | katima mulilo
# Processing Record 13 of Set 11 | penzance
# Processing Record 14 of Set 11 | basoko
# Processing Record 15 of Set 11 | staraya stanitsa
# Processing Record 16 of Set 11 | mantua
# Processing Record 17 of Set 11 | tasova
# Processing Record 18 of Set 11 | ploneour-lanvern
# Processing Record 19 of Set 11 | chiungutwa
# Processing Record 20 of Set 11 | kigoma
# Processing Record 21 of Set 11 | mondlo
# Processing Record 22 of Set 11 | orlov
# Processing Record 23 of Set 11 | tsiombe
# Processing Record 24 of Set 11 | zagora
# Processing Record 25 of Set 11 | rukban
# City not found. Skipping...
# Processing Record 26 of Set 11 | leava
# Processing Record 27 of Set 11 | maputo
# Processing Record 28 of Set 11 | strezhevoy
# Processing Record 29 of Set 11 | owode
# Processing Record 30 of Set 11 | axim
# Processing Record 31 of Set 11 | constitucion
# Processing Record 32 of Set 11 | severo-yeniseyskiy
# Processing Record 33 of Set 11 | rusape
# Processing Record 34 of Set 11 | kerikeri
# Processing Record 35 of Set 11 | panjab
# Processing Record 36 of Set 11 | todos santos
# Processing Record 37 of Set 11 | navolato
# Processing Record 38 of Set 11 | talavera
# Processing Record 39 of Set 11 | kapuskasing
# Processing Record 40 of Set 11 | akureyri
# Processing Record 41 of Set 11 | shakawe
# Processing Record 42 of Set 11 | huanuco
# Processing Record 43 of Set 11 | namibe
# Processing Record 44 of Set 11 | dum duma
# Processing Record 45 of Set 11 | smach mean chey
# City not found. Skipping...
# Processing Record 46 of Set 11 | chabahar
# Processing Record 47 of Set 11 | korla
# Processing Record 48 of Set 11 | hayma'
# City not found. Skipping...
# Processing Record 49 of Set 11 | kokofata
# City not found. Skipping...
# Processing Record 0 of Set 12 | tokar
# Processing Record 1 of Set 12 | akbarabad
# Processing Record 2 of Set 12 | sao joao da barra
# Processing Record 3 of Set 12 | bikenibeu village
# Processing Record 4 of Set 12 | mumford
# Processing Record 5 of Set 12 | san patricio
# Processing Record 6 of Set 12 | veinticinco de mayo
# Processing Record 7 of Set 12 | tchintabaraden
# Processing Record 8 of Set 12 | thinadhoo
# Processing Record 9 of Set 12 | copala
# Processing Record 10 of Set 12 | sao gabriel da cachoeira
# Processing Record 11 of Set 12 | punjai puliyampatti
# Processing Record 12 of Set 12 | sindangan
# Processing Record 13 of Set 12 | tchibanga
# Processing Record 14 of Set 12 | york
# Processing Record 15 of Set 12 | dolores
# Processing Record 16 of Set 12 | hammerfest
# Processing Record 17 of Set 12 | okha
# Processing Record 18 of Set 12 | shajiang
# Processing Record 19 of Set 12 | kavieng
# Processing Record 20 of Set 12 | egersund
# Processing Record 21 of Set 12 | gweru
# Processing Record 22 of Set 12 | ubinskoye
# Processing Record 23 of Set 12 | tazacorte
# Processing Record 24 of Set 12 | ivdel'
# Processing Record 25 of Set 12 | nieuw amsterdam
# Processing Record 26 of Set 12 | peniche
# Processing Record 27 of Set 12 | ad dabbah
# Processing Record 28 of Set 12 | pokachi
# Processing Record 29 of Set 12 | puerto san jose
# Processing Record 30 of Set 12 | san mateo del mar
# Processing Record 31 of Set 12 | pursat
# Processing Record 32 of Set 12 | hotan
# Processing Record 33 of Set 12 | lodwar
# Processing Record 34 of Set 12 | tralee
# Processing Record 35 of Set 12 | karachi
# Processing Record 36 of Set 12 | aldinga beach
# Processing Record 37 of Set 12 | kisangani
# Processing Record 38 of Set 12 | belmonte
# Processing Record 39 of Set 12 | port shepstone
# Processing Record 40 of Set 12 | khorugh
# Processing Record 41 of Set 12 | ladario
# Processing Record 42 of Set 12 | fada
# Processing Record 43 of Set 12 | kendari
# Processing Record 44 of Set 12 | kiruna
# Processing Record 45 of Set 12 | angaur state
# Processing Record 46 of Set 12 | campbell river
# Processing Record 47 of Set 12 | phan rang-thap cham
# Processing Record 48 of Set 12 | egilsstadir
# Processing Record 49 of Set 12 | murray bridge
# Processing Record 0 of Set 13 | alo
# Processing Record 1 of Set 13 | aghstafa
# Processing Record 2 of Set 13 | jiayuguan
# Processing Record 3 of Set 13 | lata
# Processing Record 4 of Set 13 | carutapera
# Processing Record 5 of Set 13 | emerald
# Processing Record 6 of Set 13 | toliara
# Processing Record 7 of Set 13 | nagqu
# Processing Record 8 of Set 13 | ozernyy
# Processing Record 9 of Set 13 | machico
# Processing Record 10 of Set 13 | stroitel'
# Processing Record 11 of Set 13 | sarupathar
# Processing Record 12 of Set 13 | amalapuram
# Processing Record 13 of Set 13 | fuente obejuna
# Processing Record 14 of Set 13 | avesta
# Processing Record 15 of Set 13 | kill devil hills
# Processing Record 16 of Set 13 | meulaboh
# Processing Record 17 of Set 13 | illizi
# Processing Record 18 of Set 13 | piedras negras
# Processing Record 19 of Set 13 | tarawa
# Processing Record 20 of Set 13 | daru
# Processing Record 21 of Set 13 | cadale
# Processing Record 22 of Set 13 | booue
# Processing Record 23 of Set 13 | bandarbeyla
# Processing Record 24 of Set 13 | port macquarie
# Processing Record 25 of Set 13 | manokwari
# Processing Record 26 of Set 13 | raghunathpur
# Processing Record 27 of Set 13 | hilo
# Processing Record 28 of Set 13 | kharp
# Processing Record 29 of Set 13 | lerwick
# Processing Record 30 of Set 13 | forbes
# Processing Record 31 of Set 13 | kone
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame({
    "City": cities,
    "Lat": city_lat,
    "Lng": city_lng,
    "Max Temp": city_max_temp,
    "Humidity": city_humidity,
    "Cloudiness": city_clouds,
    "Wind": city_wind,
    "Country": city_country,
    "Date": city_date,
    
    
})

#Drop any cities that were skipped in the previous response
city_data_df = city_data_df.dropna(how="any")

# Show Record Count
city_data_df.count()
# Out:
# City          632
# Lat           632
# Lng           632
# Max Temp      632
# Humidity      632
# Cloudiness    632
# Wind          632
# Country       632
# Date          632
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind  \
# 0        nova sintra -21.0595  164.8658     66.43        66          66  6.91
# 1          adamstown -21.0595  164.8658     66.43        66          66  6.91
# 2              lihue -21.0595  164.8658     66.43        66          66  6.91
# 3  port-aux-francais -21.0595  164.8658     66.43        66          66  6.91
# 4            ushuaia -21.0595  164.8658     66.43        66          66  6.91
#
#   Country        Date
# 0      NC  1690453571
# 1      NC  1690453571
# 2      NC  1690453571
# 3      NC  1690453571
# 4      NC  1690453571

# %%
# Export the City_Data into a csv
city_data_df.to_csv("./output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("./output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0              nova sintra -21.0595  164.8658     66.43        66          66
# 1                adamstown -21.0595  164.8658     66.43        66          66
# 2                    lihue -21.0595  164.8658     66.43        66          66
# 3        port-aux-francais -21.0595  164.8658     66.43        66          66
# 4                  ushuaia -21.0595  164.8658     66.43        66          66
#
#          Wind Country        Date
# City_ID
# 0        6.91      NC  1690453571
# 1        6.91      NC  1690453571
# 2        6.91      NC  1690453571
# 3        6.91      NC  1690453571
# 4        6.91      NC  1690453571

# %%
city_data_df = pd.DataFrame(city_data)

city_data_df.count()
# Out:
# City          606
# Lat           606
# Lng           606
# Max Temp      606
# Humidity      606
# Cloudiness    606
# Wind Speed    606
# Country       606
# Date          606
# dtype: int64

# %%
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        nova sintra  14.8667  -24.7167     73.98        83          29
# 1          adamstown -25.0660 -130.1015     66.87        60          12
# 2              lihue  21.9789 -159.3672     80.19        80          75
# 3  port-aux-francais -49.3500   70.2167     41.63        90          70
# 4            ushuaia -54.8000  -68.3000     29.86        69           0
#
#    Wind Speed Country        Date
# 0       10.76      CV  1690452461
# 1        5.19      PN  1690452462
# 2       14.97      US  1690452415
# 3       38.36      TF  1690452463
# 4        9.22      AR  1690452464

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# date_now = datetime.date(datetime.now())

x_values = city_data_df["Lat"]
y_values = city_data_df["Max Temp"]

fig1, ax1 = plt.subplots(figsize=(8,5))

# Incorporate the other graph properties
plt.scatter(x_values, y_values, edgecolor="black", linewidth=.75, marker="o", alpha=0.8)
plt.title(f"City Max Latitude vs Temperature (2022-10-18)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid()
          

# Save the figure
plt.savefig("./output_data/latitude_vs_max_temp.png", bbox_inches="tight")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x_values = city_data_df["Lat"]
y_values = city_data_df["Humidity"]

fig1, ax1 = plt.subplots(figsize=(11,8))

# Incorporate the other graph properties
plt.scatter(x_values, y_values, edgecolor="black", linewidth=.75, marker="o", alpha=0.8)
plt.title(f"City Latitude vs Humidity (2022-10-18)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()
          

# Save the figure
plt.savefig("./output_data/latitude_vs_humidity.png", bbox_inches="tight")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x_values = city_data_df["Lat"]
y_values = city_data_df["Cloudiness"]

fig1, ax1 = plt.subplots(figsize=(12,8))

# Incorporate the other graph properties

plt.scatter(x_values, y_values, edgecolor="black", linewidth=.75, marker="o", alpha=0.8)
plt.title(f"City Max Latitude vs Cloudiness (2022-10-18)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
          

# Save the figure
plt.savefig("./output_data/latitude_vs_cloudiness.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
x_values = city_data_df["Lat"]
y_values = city_data_df["Wind Speed"]

fig1, ax1 = plt.subplots(figsize=(11,8))

# Incorporate the other graph properties
plt.scatter(x_values, y_values, edgecolor="black", linewidth=.75, marker="o", alpha=0.8)
plt.title(f"City Latitude vs Wind Speed (2022-10-18)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid()
          

# Save the figure
plt.savefig("./output_data/latitude_vs_wind_speed.png", bbox_inches="tight")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, x_label, y_label, hemisphere, text_coordinates):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

    # Get regression values
    regress_values = x_values * slope + intercept
    
    # Create line equation string
    line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
    
    # Generate plots     
    fig1, ax1 = plt.subplots(figsize=(12,8))
    plt.scatter(x_values, y_values, edgecolor="black", linewidth=1, marker="o", alpha=0.8)
    plt.plot(x_values,regress_values,"r-")
    
    # Add in labels 
    plt.title(f"{hemisphere} Hemisphere - {x_label} vs {y_label}",fontsize = 15)
    plt.xlabel(x_label,fontsize=14)
    plt.ylabel(y_label,fontsize=14)
    plt.annotate(line_eq, text_coordinates, fontsize=20, color="red")
    
    
#     if ylim is not None:
#         plt.ylim(0, ylim)
#     plt.annotate(line_eq, text_coordinates, fontsize=20, color="red")
    
    # Print r square value
    
    print(f"The r-value is: {rvalue**2}")
    correlation = st.pearsonr(x_values,y_values)
    print(f"The correlation between both factors is {round(correlation[0],2)}")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            nova sintra  14.8667  -24.7167     73.98        83          29
# 2                  lihue  21.9789 -159.3672     80.19        80          75
# 5                lobujya  27.9500   86.8167     42.58        93         100
# 6                 bethel  41.3712  -73.4140     73.90        91           0
# 9  coahuayana de hidalgo  18.7000 -103.6583     76.33        94         100
#
#    Wind Speed Country        Date
# 0       10.76      CV  1690452461
# 2       14.97      US  1690452415
# 5        5.95      NP  1690452464
# 6        6.91      US  1690452465
# 9        4.47      MX  1690452467

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 1          adamstown -25.0660 -130.1015     66.87        60          12
# 3  port-aux-francais -49.3500   70.2167     41.63        90          70
# 4            ushuaia -54.8000  -68.3000     29.86        69           0
# 7          grytviken -54.2811  -36.5092     33.19        99         100
# 8       port moresby  -9.4431  147.1797     75.72        84          97
#
#    Wind Speed Country        Date
# 1        5.19      PN  1690452462
# 3       38.36      TF  1690452463
# 4        9.22      AR  1690452464
# 7       10.09      GS  1690452466
# 8       13.49      PG  1690452466

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Latitude", "Max Temp (F)", "Northern", (-5,10))


# Save the output to png
plt.savefig("./output_data/northern_linear_lat_vs_max_temp.png", bbox_inches="tight")
plt.show()
# Out:
#   Cell In[17], line 5
#     plt.text(f"The r-value is: {rvalue**2}")r-value is: {rvalue**2}")
#                                                                    ^
# SyntaxError: unterminated string literal (detected at line 5)

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Latitude", "Max Temp (F)", "Southern", (-52, 75))

# Save the output to png
plt.savefig("./output_data/southern_linear_lat_vs_max_temp.png", bbox_inches="tight")
plt.show()
# Out:
# The r-value is: 0.5920311808548367
# The correlation between both factors is 0.77

# %% [markdown]
# **Discussion about the linear relationship:** From looking at the r value in both hemispheres, it it evident that there is a strong correlation between the lattitude and the maximum temperature. In the southern hemisphere, the correlation is stronger (r value .77) indicating that as we get further away from the equator, the temperature decreases in a more linear manner.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']

# Plot the linear regression and save r value
plot_linear_regression(x_values, y_values, "Latitude", "Humidity (%)", "Northern",(50,50))

# Save the output to png
plt.savefig("./output_data/northern_linear_lat_vs_humidity.png", bbox_inches="tight")
plt.show()
# Out:
# The r-value is: 0.0014868547905884668
# The correlation between both factors is -0.04

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']

# Plot the regression, calculate r value
plot_linear_regression(x_values, y_values, "Latitude", "Humidity (%)", "Southern", (-50, 50))

# Save the output as png
plt.savefig("./output_data/southern_linear_lat_vs_humudity.png", bbox_inches="tight")
plt.show()
# Out:
# The r-value is: 0.0034689903904610913
# The correlation between both factors is -0.06

# %% [markdown]
# **Discussion about the linear relationship:** In both scatterplots there can be seen a weak correlation or r value below .005 therefore indicating there is a wek relationship between humidity and latitude in both southern and northen hemispheres.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']
plot_linear_regression(x_values, y_values, "Latitude", "Cloudiness (%)", "Northern", (20, 60))

plt.savefig("./output_data/northern_linear_lat_vs_cloudiness.png", bbox_inches="tight")
plt.show()
# Out:
# The r-value is: 0.021919252171645663
# The correlation between both factors is -0.15

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']
plot_linear_regression(x_values, y_values, "Latitude", "Cloudiness (%)", "Southern", (-45, 60))


plt.savefig("./output_data/southern_linear_lat_vs_cloudiness.png", bbox_inches="tight")
plt.show()
# Out:
# The r-value is: 0.0037165419115388863
# The correlation between both factors is -0.06

# %% [markdown]
# **Discussion about the linear relationship:** In both scatterplots the values are too varied to produce a strong correlation, therefore we can conclude there is no correlation between cloudiness and latitude in either hemisphere.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']

# Plot linear regression and calculate r value
plot_linear_regression(x_values, y_values, "Latitude", "Wind Speed (mph)", "Northern",(20, 25))

# Save the scatterplot as png
plt.savefig("./output_data/northern_linear_lat_vs_wind_speed.png", bbox_inches="tight")
plt.show()
# Out:
# The r-value is: 0.024132808705232347
# The correlation between both factors is -0.16

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']

# Plot linear regression and calculate r value
plot_linear_regression(x_values, y_values, "Latitude", "Wind Speed (mph)", "Southern",(-40, 25))

# Save the scatterplot as png
plt.savefig("./output_data/southern_linear_lat_vs_wind_speed.png", bbox_inches="tight")
plt.show()
# Out:
# The r-value is: 0.0209843399343203
# The correlation between both factors is -0.14

# %% [markdown]
# **Discussion about the linear relationship:** In both scatterplots we can derive no correlation between wind speed and latitude, therefore we can conclude no correlation between distance from the equator and wind speed in either hemisphere.
